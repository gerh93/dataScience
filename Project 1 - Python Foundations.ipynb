# %% [markdown]
# # Cardio Good Fitness Project
#
# ## Introduction
# Cardio Good Fitness is a retail store for fitness equipment. This project will contain especifically data for customers interested in purchasing Treadmill product(s).
#
# # Problem Definition
# ## Objective
# Explore and extract actionable insights and recommendations that will help the company target new customers.
#
# ## Key Questions:
# 1. What are the customers characteristics per products.
# 2. What customers are purchasing which type of product.
# 3. What are the relationships between different attributes per customers.
# 4. What is the relationship between products.
# 5. What is the dataset basic content.
# 6. How can we target more customers.
#
#
# ## Data:
#  1. Product: Treadmill's model number.
#  2. Age: Customer's age.
#  3. Gender: Customer's gender.
#  4. Education: Customer's education - in years.
#  5. Marital Status: Customer's marital status.
#  6. Usage: Average number of times the customer wants to use the treadmill every week.
#  7. Fitness: Self rated fitness score for customer
#              Ratings: 5 - Very fit
#                       1 - Very unfit
#  8. Income: Customer's income.
#  9. Miles: Customer's expected miles to run.

# %% [markdown]
# ### Import the necessary libraries - pandas, numpy, seaborn and matplottib.pyplot

# %%
import warnings
warnings.filterwarnings ('ignore')

# %%
# Import CSV file using pandas
# Import numpy to perform complex algebra functions
# Import matplotlib.pyplot to make changes to figures (adding labels)
# Import seaborn to add high level features to graphs 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Enables Python to plot graphs in Jupyter notebook
# %matplotlib inline 
import seaborn as sns
sns.set(color_codes=True) # adds background to the graphs

# %% [markdown]
# ### Import / Read dataset

# %%
# Get CSV file including default index locations column
orig_df = pd.read_csv('CardioGoodFitness.csv')
orig_df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
# copy data to new variable to avoid making changes to original dataframe
copy_df = orig_df.copy()
copy_df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
# Output first 10 rows of Dataset
copy_df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %% [markdown]
# ##### Observations
#  - Product shows the treadmill's code.
#  - Gender and MaritalStatus are categorical variables.
#  - Age, Education, usage, fitness, income, miles are int numerical          variables.

# %% [markdown]
# # Preliminary Data Analysis

# %%
copy_df.shape
# Out:
# (180, 9)

# %% [markdown]
# - the Dataset has 180 rows and 9 columns

# %%
# Check Dataframe info
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# ##### Observations
# - All columns have 180 entries indicating there are no missing values in   any column.
# - Some DataTypes do not correspond with the data set.
#     - Product, Gender, MaritalStatus are not the correct dataype. They         should = categorical variables.
#     - Age, Education, Usage, Fitness, Income, Miles are correct datatype       = numerical variables.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Normalizing the Datatypes
# - There are no missing values in the dataframes. No need to run any     functions to fix this.
# - Values = object in Dtype column will be converted to categorical type for memory efficiency purposes.

# %%
copy_df['Product'] = copy_df.Product.astype('category')
copy_df['Gender'] = copy_df.Gender.astype('category')
copy_df['MaritalStatus'] = copy_df.MaritalStatus.astype('category')

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    category
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    category
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    category
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: category(3), int64(6)
# memory usage: 9.4 KB

# %% [markdown]
# ##### Observations
# - All datatypes of columns Product, Gender and MaritalStatus have been     fixed.
# - Memory usage decreased from 12.8+ KB to 9.4KB. Making this conversion   more efficient (memory wise)

# %%
copy_df.describe(include = 'all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ##### Observations
# - There are 3 unique products.
# - Top Product is TM195.
# - Top Gender buying treadmills are Male.
# - Top MaritalStatus for customers is Partnered.
# - The average customer's age purchasing treadmills is 28 years old.
# - The youngest customers purchasing treadmills are 24 years old - Q1 = 25%
# - The next youngest customers purchasing treadmills are 26 years old - Q2 = 50% (bellow the median).
# - The next group age purchasing treadmills are 33 years old - Q3 = 75% (above the median)
# - The highest customer's age purchasing treadmills is 50 years old.

# %% [markdown]
# # EDA
# ### Exploring Numerical Variables

# %% [markdown]
# ### Uni-variate Graph Analysis

# %%
# Analysis for Product
# Function to annotate the percentage for data in x-axis
def var_perc (plot, feature):
    total = len(feature)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x=p.get_x() + p.get_width()/2-0.05
        y=p.get_y() + p.get_height()
        ax.annotate(percentage, (x,y), size =15)

plt.figure(figsize=(7,7))
ax = sns.countplot(copy_df['Product'], palette="PuBuGn_r")
var_perc(ax, copy_df['Product'])

sns.displot(copy_df['Product'], kde=True);

# %%
# Analysis for Marital Satus 
plt.figure(figsize=(7,7))
ax = sns.countplot(copy_df['MaritalStatus'], palette="PuBuGn")
var_perc(ax, copy_df['MaritalStatus'])

sns.displot(copy_df['MaritalStatus'], kde=True);

# %%
# Analysis for Education
plt.figure(figsize=(7,7))
ax = sns.countplot(copy_df['Education'], palette="PuBuGn")
var_perc(ax, copy_df['Education'])

sns.displot(copy_df['Education'], kde=True);

# %%
# Analysis for Age
plt.figure(figsize=(15,7))
ax = sns.countplot(copy_df['Age'], palette = "mako_r")
var_perc(ax, copy_df['Age'])

sns.displot(copy_df['Age'], kde=True);

# %%
# Analysis for Gender
plt.figure(figsize=(15,7))
ax = sns.countplot(copy_df['Gender'], palette = "mako_r")
var_perc(ax, copy_df['Gender'])

sns.displot(copy_df['Gender'], kde=True);

# %%
# Analysis for Usage
plt.figure(figsize=(15,7))
ax = sns.countplot(copy_df['Usage'], palette = "mako_r")
var_perc(ax, copy_df['Usage'])

sns.displot(copy_df['Usage'], kde=True);

# %% [markdown]
# ##### Observations
# - For Product TM195: there are aprox 80 customers that purchased this treadmill. Confirms above observation from .describe() output. This is top the product, purchased 44% by customers.
# - For Product TM498: there are aprox 60 customers that purchased this treadmill. Purchased 33.3% by customers.
# - For Product TM798: there are aprox 40 customers that purchased this treadmill. Purchased 22.2% by customers.
# - The highest customer age purchasing treadmills are around 23-25 years old. Confirms above observation from .describe() output.
# - There is about 1 customer of age 50 purchasing treadmills.
# - The majority of purchasing customers are partenered.
# - The majority of purchasing customers are highly educated with at least 16 years of Education.
# - The majority of purchasing customers are Male.
# - 3 times a week is the most common number customers use the treadmill a week.

# %% [markdown]
# ### Bi-variate Graph Analysis

# %%
# Analysis for Age/Income
g = sns.jointplot(copy_df['Age'], copy_df['Income'], kind="hist");
g.plot_marginals(sns.rugplot, color="r", height=.20, clip_on=False);

# %% [markdown]
# ##### Observations
# - There is a positive relationship between Age and Income for customers. The lower the age the lower the income per customer.
# - The histograms show the highest concentration of treadmill purchasers fall between the age of 20-38 with an income range of 45,000-70,000.
# - Customers between 40-50 years old seem to purchase a treadmill once they reach an income of ~50,000 to 100,000.
# - Customers between 40-50 years old purcahse less treadmills than customers within the age group of 20-38.

# %%
# Analysis Education/Income
g1=sns.jointplot(copy_df['Education'], copy_df['Income'], kind="reg");
g1.plot_marginals(sns.rugplot, color="r", height=.20);

# %% [markdown]
# ##### Observations
# - There is a positive relationship between Education and Income. The lower the years of education the lower the income.
# - Customer's within the range of 13-16 years of Education have an Income of aprox 30,000-68,000. This group of customers seem to purchase a treadmill with more frequency than rest.
# - Customers with 18 yeas of Education have an Income of aprox 50,000-100,000+ is the next biggest purchasing group.

# %%
# Analysis for Produt/Income
sns.stripplot(copy_df['Product'], copy_df['Income'], jitter=True);

# %% [markdown]
# ##### Observations
# - Customers with Income between <30,000-70,000 tend to purchase Product TM195.
# - Customers with Income between 50,000-100,000+ tend to purchase Product TM798.

# %% [markdown]
# ### Multi-Variate Graph Analysis

# %%
# Analysis Age/Education/Income/Usage
sns.pairplot(copy_df[['Age', 'Education', 'Income', 'Usage']], 
             corner=False, palette="Set1");

# %% [markdown]
# ##### Observations
# - Age and Education have a positive relationship. The lower the Age and the highest the education the customer is more likely to purchase a treadmill.
# - Age and Income have a positive relationship. The lower the Age, the customer has less Income to purchase a treadmill.
# - Age and Usage have a positive relationship. The lower the Age the customer is more likely to use the treadmill 2-5 times a week.
# - Education and Income have a positive relationship. "See observation above for conclusion". Graph = g1.
# - Education and Usage have a positive relationship. The more Education have the more Usage the customer gets from a treadmill.
# - Income and Usage have a positive relationship. The more Icome a customer has the more Usage they get from a treadmill. Customer uses treadmill up to 5 times a week.

# %%
# Analysis for Produt/Age/MaritalStatus
sns.stripplot(copy_df['Product'], copy_df['Age'], copy_df['MaritalStatus'], jitter=True);

# %% [markdown]
# ##### Observations
# - The highest selling Product is TM195.
# - Product TM195 is being purchased by customers between the age of 18-35.
# - Product TM195 is mostly being purchased by single customers.
# - The second highest selling Product is TM798.
# - Product TM798 is mostly being purchased by single customers between the ages of 24-30.

# %%
# Correlation check for numerical variables 
num_var = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']
num_corr= copy_df[num_var].corr()

# Graph Heatmap
plt.figure(figsize=(15,10))
sns.heatmap(num_corr, annot=True, cmap="YlGnBu");

# %% [markdown]
# ##### Observations
# - As stated on previous observations there is a high correlation between Education and Income. The higher the Education the higher the Income.
# - Usage and Fitness level have a high correlation. The higher the Fitness level the higher the Usage for custmers per week.
# - Usage and Miles have a high correlation. The more Miles the customer runs the more Usage the treadmill will have.
# - Fitness level and Miles have a high correlation. The higher the Fitness level the more Miles the customer will run.

# %%
# Relationship analysis between Product/Income/Gender/MaritalStatus
fig, ax = plt.subplots()
# Size of Lineplot
fig.set_size_inches(17, 10)
sns.lineplot(data=copy_df, x="Product", y="Income", hue="Gender", style="MaritalStatus",
            markers=True, dashes=True, palette="mako_r", legend="full");

# %% [markdown]
# ##### Observations
# - Product TM195 tends to be highly purchased equally, by single and partenered females and males with an Income between 45,000-50,000.
# - Product TM498 tends to be highly purchased by partnered females and males with an Income between 47,000-50,000.
# - Product TM798 tends to be purchased by single and partnered females and males with an Income between 58,000-100,000+.

# %%
# Relationship analysis between Product, Age, Gender
plt.figure(figsize=(10,10))
sns.boxplot(copy_df['Age'], copy_df['Product'], copy_df['Gender'], linewidth=3, palette='YlGnBu_r');
plt.xlabel('Age');
plt.ylabel('Product');

# %%
# Relationship analysis between Product, Age, Gender
plt.figure(figsize=(10,10))
sns.boxplot(copy_df['Income'], copy_df['Product'], copy_df['Gender'], linewidth=3, palette='YlGnBu_r');
plt.xlabel('Income');
plt.ylabel('Product');

# %% [markdown]
# ##### Observations
# - Product TM195 has the highest purchase rate between all products for customers within the age group of 23-34.
# - There is a clear difference in purchase ratings between all 3 products.
# - Product TM798 is the lowest pruchased Product.
# - Across all 3 Products Male customers tend to purchase a treadmill more often.
# - Customers with higher Income tend to pruchase  Product TM798.
# - Cuatomers with lower Income tend to purchase Prpduct TM195 and TM498

# %%
# Relationship Analysis between Age/Income/Product
plt.figure(figsize=(10,15));
g2 = sns.catplot(x="Age", y="Income", 
                 hue="Product", col="Product",
                 data=copy_df, kind="box",
                 height=10, aspect=.75);

# %% [markdown]
# ##### Observations
# - For Product TM195 the highest age group purchasing this Product are between 19-38 with an Income of 30,000-63,000.
# - For Product TM498 the highest age group pruchasing this Product are between 23-34 with an Income of 40,000-68,000.
# - For Product TM798 the highest age group purchasing this Product are between 23-31 with an Income of 48,000-103,000.
# - Products TM195 and TM498 are more popular for younger customers between 19-38 years old with an Income of ~30,000-68,000.
# - Product TM798 is more popular for customers between 23-31 years old with an Income of 48,000-103,000.

# %%
# Relationship analysis between Age, Income, Product
plt.figure(figsize=(15,10))
sns.boxplot(x="Age", y="Income", hue="Product", linewidth=2, palette="YlGnBu_r", data=copy_df);

# %% [markdown]
# ##### Observations (Same as above)
# - Closer view to data.
# -For Product TM195 the highest age group purchasing this Product are between 19-38 with an Income of 30,000-63,000.
# - For Product TM498 the highest age group pruchasing this Product are between 23-34 with an Income of 40,000-68,000.
# - For Product TM798 the highest age group purchasing this Product are between 23-31 with an Income of 48,000-103,000.
# - Products TM195 and TM498 are more popular for younger customers between 19-38 years old with an Income of ~30,000-68,000.
# - Product TM798 is more popular for customers between 23-31 years old with an Income of 48,000-103,000.

# %%
# Relationship analysis between Age, Income, Education
plt.figure(figsize=(20,10));
ax = sns.barplot(x="Age", y="Income", hue="Education", 
                 data=copy_df, dodge=False, palette="YlGnBu_r");

# %% [markdown]
# ##### Observations
# - The majority of customers purchasing treadmills have between 16-20 years of education. This Customers are between 22-24, 28-35, 38-50 years old.
# - Customers with 16-20 years of education have an income of 68,000-105,000 dollars.

# %%
# Relationship between Age, Education, Product
plt.figure(figsize=(15,10));
sns.boxplot(x="Age", y="Education", hue="Product", 
            linewidth=2, palette="YlGnBu_r", data=copy_df);

# %% [markdown]
# ##### Obervations
# - Customers with 13-17 years in Education tend to purchase more often Product TM195. The purchasing customer's Age group ranges between 18-29.
# - Customers with 13-17 years in Education tend to purchase more often Product TM498. The purchasing customer's Age group ranges between 21-24.
# - Customers with 15-20 years in Education tend to purchase more often Product TM798. The purchasing customer's Age group ranges between 22-31.

# %%
#  Relationship analysis between Age, Income, Marital Status
plt.figure(figsize=(15,10));
sns.boxplot(x="Age", y="Income", hue="MaritalStatus", 
            linewidth=2, palette="YlGnBu_r", data=copy_df);

# %% [markdown]
# ##### Observations
# - Partnered customers are the biggest purchasing group.
# - Partnered customers are between 19-38 years old.
# - Partnered customers have greater Income than single customers.
# - Single customers have less Income than partnered customers.

# %%
# Relationship between Marital Status, Income, Product        
plt.figure(figsize=(15,10))
sns.boxplot(x="MaritalStatus", y="Income", hue="Product", 
            linewidth=2, palette="YlGnBu_r", data=copy_df);

# %% [markdown]
# ##### Observations
# - Partnered customers with an Income of 41,000-55,000 tend to purchase Product TM195 more often.
# - Partnered customers with an Income of 68,000-93,000 tend to purchase Product TM798 more often.
# - Single customers with an Incom of 52,000-88,000 tend to purchase Produt TM798 more often.

# %%
# Relationship between Marital Status, Income, Product        
plt.figure(figsize=(15,10))
sns.boxplot(x="Usage", y="Age", hue="Product", 
            linewidth=2, palette="YlGnBu_r", data=copy_df);

# %%
# Relationship between Marital Status, Income, Product        
plt.figure(figsize=(15,10))
sns.boxplot(x="Usage", y="MaritalStatus", hue="Product", 
            linewidth=2, palette="YlGnBu_r", data=copy_df);

# %% [markdown]
# ##### Observations
# - Customers across the ages of 24-35 use the product TM194 and TM498 2-4 times a week.
# - Customers that purchased product TM798 use treadmill 4-6 times a week.
# - Partenered customers tendo to have more usage to the product than single customers.

# %% [markdown]
# ## Conclusion
# I analyzed the data of 3 different products offered by Cardio Good Fitness (the "Firm"), utilizing the customer data set given to me by the Firm. Through my research and observation, I have come to the conclusions that the average customer profile is a partnered male between 24-34 years old, with 16 years of education and an annual income of 55,000.
#
# The analysis conclusions are listed below:
#
# 1. The highest selling product is TM195.
# 2. The majority of customer that purchase product TM195 fall between the ages of 24-34.
# 3. The majority of customers that have had 13-17 years of education purchase product TM195 and TM498.
# 4. Customers with higher education and higher income gravitate to product TM798.
# 5. The majority of single female customers that stated they utilized their treadmill 2-4 times a week purchased Product TM195.
# 6. The majority of partnered male customers that stated they utilized their treadmill 2-4 times a week purchased product TM498
# 7. The majority of single male customers that stated they utilized their treadmill 4-6 times a week purchased Product TM798.
# 8. Customers between the age of 40-50 years old purchased less treadmills than customers within the age group of 20-38.
# 9. Customers between 40-50 years old purchased treadmills once they reached an income of at least ~50,000.

# %% [markdown]
# ## Recommendations to Cardio Good Fitness
#
# 1. Since product TM195 is the highest selling product, apply a significant portion of the Firm's marketing budget on individuals that are part of Gen Y (24-40 year old), with at least an associates degree, starting a career with an entry level position (income of 30,000 - 60,000).
#
#
# 2. Discontinue the production of product TM498. This product resonates with the same audience as product TM195 with lower sales. The phasing out of product TM498 will streamline the Firm's products offering, allowing management to efficiently control its resources and outputs.
#
#
# 3. Product TM798 resonates with a similar age demographic as TM195. However, these customers have a higher income (Income of 50,000 to 100,000) and are more educated than purchasers of product TM195. Therefore, target higher income individuals within Gen Y (24-40 year old) population and make sure to upsale and educate individuals on the different features between product TM195 and TM798.
#
#
# 4. The product offerings of the Firm resonate heavily with individuals between the ages of 22-35, with little interest from the older individuals (40+ years old). The Firm would benefit from creating a new product that focuses on the older demographic (40-50 year old) to capture a new market.
